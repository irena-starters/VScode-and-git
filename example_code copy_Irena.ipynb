# %% [markdown]
# # Visual Studio Code and git control
#
# Visual Studio Code is a lightweight but powerful source code editor. It comes with built-in support for JavaScript, TypeScript and Node.js and has a rich ecosystem of extensions for other languages, like Python and R. VS Code can be obtained from [here](https://code.visualstudio.com/Download) and the installation instructions can be read [here](https://code.visualstudio.com/docs/setup/setup-overview).
#
# Visual Studio Code has integrated source control management (SCM) and includes Git version control which allows to keep tract of files over time. Git is a program for managing source code, while GitHub hosts a copy of that code and repository online. In case you do not have git installed already, you can obtain it from [here](https://git-scm.com/downloads).
#
# ## Cloning a repository
#
# Once a new window has been opened, to go to sorce control (**View** -> **Source control**). From here, one can open a folder containing git repository or clone a repository and commit all changes to GitHub. (I presume all of you have a GitHub account; if not I can send you the file) For the purposes of our code club, I prepared publicly available repository (https://github.com/irena-starters/VScode-and-git.git). Copy this link and select a repository destination (directory in which this script will be located). Open the cloned repository.

# %% [markdown]
# ## Visualizations using seaborn
#
# In the following example, we will plot some data using the seaborn library. This library doesn't come pre-installed with python, so one should install it in the terminal. Simply go to **Terminal** -> **New terminal** and type:
# > pip install seaborn
#
# Then, you can import the package with the following code:

# %%
import seaborn as sns
# %matplotlib inline   
sns.set_theme(style="whitegrid")

# %% [markdown]
# Since seaborn comes with buit-in datasets, we can load that that and start plotting it. We will load a data frame called tips.

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# The seaborn package is a data visualization package and it contains many pre-buit plotting options. For example using boxplot() function, one can visualize the data with boxplots and using violinplot() function, one can visualize the data with violin plots. For example:

# %%
sns.boxplot(x="day", y="total_bill", data=tips, hue= 'sex', palette='Set1')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day", y="total_bill", data=tips,palette='pastel')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Differnt examples of what can be plotted using seaborn package, can be found [here](https://seaborn.pydata.org/examples/index.html).

# %% [markdown]
# ## Tasks
#
# #### Switch to a new branch
#
# In order to test how version control works with git, I would like you to make a new branch in the terminal by typing:
# > git checkout -b your_name
#
# #### Modify the script
#
# Once you are in your branch, modify this script in a following manner:
#
# 1) The boxplot above should now be grouped by the sex of the person and a different palette should be used (hint: use hue parameter).
#
# 2) Make a new violin plot that examines the distributions of tips depending on time of the day. Group the data by the smoking status.

# %%
sns.violinplot(x="time", y="tip", hue='smoker', data=tips,palette='pastel')
# Out:
# <AxesSubplot: xlabel='time', ylabel='tip'>

# %% [markdown]
# #### Examine the changes
#
# Save the file and go on source control to view the changes that you have made (press the M next to the file). Here you can see what you have changed since the last time that you have commited your code.
#
# #### Commit the changes to your branch
#
# After you are satidfied with your changes, commit them to your branch. Don't forget to write a message when commiting the changes (e.g. task finished).

# %% [markdown]
# ## Great job!
